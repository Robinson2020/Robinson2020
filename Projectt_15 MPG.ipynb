# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('mpg.csv')
df
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model_year  origin                       name
# 0            70       1  chevrolet chevelle malibu
# 1            70       1          buick skylark 320
# 2            70       1         plymouth satellite
# 3            70       1              amc rebel sst
# 4            70       1                ford torino
# ..          ...     ...                        ...
# 393          82       1            ford mustang gl
# 394          82       2                  vw pickup
# 395          82       1              dodge rampage
# 396          82       1                ford ranger
# 397          82       1                 chevy s-10
#
# [398 rows x 9 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
# mpg             398 non-null float64
# cylinders       398 non-null int64
# displacement    398 non-null float64
# horsepower      398 non-null object
# weight          398 non-null int64
# acceleration    398 non-null float64
# model_year      398 non-null int64
# origin          398 non-null int64
# name            398 non-null object
# dtypes: float64(3), int64(4), object(2)
# memory usage: 28.1+ KB

# %%
df.isnull().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      0
# weight          0
# acceleration    0
# model_year      0
# origin          0
# name            0
# dtype: int64

# %%
df.describe()
# Out:
#               mpg   cylinders  displacement       weight  acceleration  \
# count  398.000000  398.000000    398.000000   398.000000    398.000000
# mean    23.514573    5.454774    193.425879  2970.424623     15.568090
# std      7.815984    1.701004    104.269838   846.841774      2.757689
# min      9.000000    3.000000     68.000000  1613.000000      8.000000
# 25%     17.500000    4.000000    104.250000  2223.750000     13.825000
# 50%     23.000000    4.000000    148.500000  2803.500000     15.500000
# 75%     29.000000    8.000000    262.000000  3608.000000     17.175000
# max     46.600000    8.000000    455.000000  5140.000000     24.800000
#
#        model_year      origin
# count  398.000000  398.000000
# mean    76.010050    1.572864
# std      3.697627    0.802055
# min     70.000000    1.000000
# 25%     73.000000    1.000000
# 50%     76.000000    1.000000
# 75%     79.000000    2.000000
# max     82.000000    3.000000

# %%
dfcor=df.corr()
dfcor
# Out:
#                    mpg  cylinders  displacement    weight  acceleration  \
# mpg           1.000000  -0.775396     -0.804203 -0.831741      0.420289
# cylinders    -0.775396   1.000000      0.950721  0.896017     -0.505419
# displacement -0.804203   0.950721      1.000000  0.932824     -0.543684
# weight       -0.831741   0.896017      0.932824  1.000000     -0.417457
# acceleration  0.420289  -0.505419     -0.543684 -0.417457      1.000000
# model_year    0.579267  -0.348746     -0.370164 -0.306564      0.288137
# origin        0.563450  -0.562543     -0.609409 -0.581024      0.205873
#
#               model_year    origin
# mpg             0.579267  0.563450
# cylinders      -0.348746 -0.562543
# displacement   -0.370164 -0.609409
# weight         -0.306564 -0.581024
# acceleration    0.288137  0.205873
# model_year      1.000000  0.180662
# origin          0.180662  1.000000

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
sns.heatmap(dfcor)

# %%
plt.figure(figsize=(10,6))
sns.heatmap(dfcor,cmap='YlOrRd_r',annot=True)

# %%
plt.figure(figsize=(10,6))
sns.heatmap(dfcor,cmap='YlOrRd_r',annot=True)

# %%
df['displacement'].plot.box()

# %%
df.head(50)
# Out:
#      mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0   18.0          8         307.0        130    3504          12.0
# 1   15.0          8         350.0        165    3693          11.5
# 2   18.0          8         318.0        150    3436          11.0
# 3   16.0          8         304.0        150    3433          12.0
# 4   17.0          8         302.0        140    3449          10.5
# 5   15.0          8         429.0        198    4341          10.0
# 6   14.0          8         454.0        220    4354           9.0
# 7   14.0          8         440.0        215    4312           8.5
# 8   14.0          8         455.0        225    4425          10.0
# 9   15.0          8         390.0        190    3850           8.5
# 10  15.0          8         383.0        170    3563          10.0
# 11  14.0          8         340.0        160    3609           8.0
# 12  15.0          8         400.0        150    3761           9.5
# 13  14.0          8         455.0        225    3086          10.0
# 14  24.0          4         113.0         95    2372          15.0
# 15  22.0          6         198.0         95    2833          15.5
# 16  18.0          6         199.0         97    2774          15.5
# 17  21.0          6         200.0         85    2587          16.0
# 18  27.0          4          97.0         88    2130          14.5
# 19  26.0          4          97.0         46    1835          20.5
# 20  25.0          4         110.0         87    2672          17.5
# 21  24.0          4         107.0         90    2430          14.5
# 22  25.0          4         104.0         95    2375          17.5
# 23  26.0          4         121.0        113    2234          12.5
# 24  21.0          6         199.0         90    2648          15.0
# 25  10.0          8         360.0        215    4615          14.0
# 26  10.0          8         307.0        200    4376          15.0
# 27  11.0          8         318.0        210    4382          13.5
# 28   9.0          8         304.0        193    4732          18.5
# 29  27.0          4          97.0         88    2130          14.5
# 30  28.0          4         140.0         90    2264          15.5
# 31  25.0          4         113.0         95    2228          14.0
# 32  25.0          4          98.0          ?    2046          19.0
# 33  19.0          6         232.0        100    2634          13.0
# 34  16.0          6         225.0        105    3439          15.5
# 35  17.0          6         250.0        100    3329          15.5
# 36  19.0          6         250.0         88    3302          15.5
# 37  18.0          6         232.0        100    3288          15.5
# 38  14.0          8         350.0        165    4209          12.0
# 39  14.0          8         400.0        175    4464          11.5
# 40  14.0          8         351.0        153    4154          13.5
# 41  14.0          8         318.0        150    4096          13.0
# 42  12.0          8         383.0        180    4955          11.5
# 43  13.0          8         400.0        170    4746          12.0
# 44  13.0          8         400.0        175    5140          12.0
# 45  18.0          6         258.0        110    2962          13.5
# 46  22.0          4         140.0         72    2408          19.0
# 47  19.0          6         250.0        100    3282          15.0
# 48  18.0          6         250.0         88    3139          14.5
# 49  23.0          4         122.0         86    2220          14.0
#
#     model_year  origin                          name
# 0           70       1     chevrolet chevelle malibu
# 1           70       1             buick skylark 320
# 2           70       1            plymouth satellite
# 3           70       1                 amc rebel sst
# 4           70       1                   ford torino
# 5           70       1              ford galaxie 500
# 6           70       1              chevrolet impala
# 7           70       1             plymouth fury iii
# 8           70       1              pontiac catalina
# 9           70       1            amc ambassador dpl
# 10          70       1           dodge challenger se
# 11          70       1            plymouth 'cuda 340
# 12          70       1         chevrolet monte carlo
# 13          70       1       buick estate wagon (sw)
# 14          70       3         toyota corona mark ii
# 15          70       1               plymouth duster
# 16          70       1                    amc hornet
# 17          70       1                 ford maverick
# 18          70       3                  datsun pl510
# 19          70       2  volkswagen 1131 deluxe sedan
# 20          70       2                   peugeot 504
# 21          70       2                   audi 100 ls
# 22          70       2                      saab 99e
# 23          70       2                      bmw 2002
# 24          70       1                   amc gremlin
# 25          70       1                     ford f250
# 26          70       1                     chevy c20
# 27          70       1                    dodge d200
# 28          70       1                      hi 1200d
# 29          71       3                  datsun pl510
# 30          71       1           chevrolet vega 2300
# 31          71       3                 toyota corona
# 32          71       1                    ford pinto
# 33          71       1                   amc gremlin
# 34          71       1     plymouth satellite custom
# 35          71       1     chevrolet chevelle malibu
# 36          71       1               ford torino 500
# 37          71       1                   amc matador
# 38          71       1              chevrolet impala
# 39          71       1     pontiac catalina brougham
# 40          71       1              ford galaxie 500
# 41          71       1             plymouth fury iii
# 42          71       1             dodge monaco (sw)
# 43          71       1      ford country squire (sw)
# 44          71       1           pontiac safari (sw)
# 45          71       1    amc hornet sportabout (sw)
# 46          71       1           chevrolet vega (sw)
# 47          71       1              pontiac firebird
# 48          71       1                  ford mustang
# 49          71       1            mercury capri 2000

# %%
import sklearn
from sklearn.preprocessing import LabelEncoder,OneHotEncoder
import pandas as pd
le=LabelEncoder()
df['name']=le.fit_transform(df['name'])
df.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model_year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
# 3  16.0          8         304.0        150    3433          12.0          70
# 4  17.0          8         302.0        140    3449          10.5          70
#
#    origin  name
# 0       1    49
# 1       1    36
# 2       1   231
# 3       1    14
# 4       1   161

# %%
df['name'].value_counts()
# Out:
# 156    6
# 266    5
# 150    5
# 10     5
# 7      4
#       ..
# 187    1
# 186    1
# 185    1
# 184    1
# 0      1
# Name: name, Length: 305, dtype: int64

# %%
df['model_year'].value_counts()
# Out:
# 73    40
# 78    36
# 76    34
# 82    31
# 75    30
# 81    29
# 80    29
# 79    29
# 70    29
# 77    28
# 72    28
# 71    28
# 74    27
# Name: model_year, dtype: int64

# %%
df['cylinders'].value_counts()
# Out:
# 4    204
# 8    103
# 6     84
# 3      4
# 5      3
# Name: cylinders, dtype: int64

# %%
df.hist(figsize = (8,8),          # Plot histogram
                 bins=50)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002BB2C1200C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002BB2FBA5748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002BB2F2C88C8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000002BB2F2F8F08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002BB2F334588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002BB2F369088>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000002BB2F399DC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002BB2F3D1B48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002BB2F3D8988>]],
#       dtype=object)

# %%
df['weight'].plot.box()

# %%
df['acceleration'].plot.box()

# %%
df['mpg'].plot.box()

# %%
sns.pairplot(df)
plt.show()

# %%
#separating the input variable
import numpy as np
df_x=df.drop(columns=["mpg"])
y=df['mpg']
df_x
# Out:
#      cylinders  displacement horsepower  weight  acceleration  model_year  \
# 0            8         307.0        130    3504          12.0          70
# 1            8         350.0        165    3693          11.5          70
# 2            8         318.0        150    3436          11.0          70
# 3            8         304.0        150    3433          12.0          70
# 4            8         302.0        140    3449          10.5          70
# ..         ...           ...        ...     ...           ...         ...
# 393          4         140.0         86    2790          15.6          82
# 394          4          97.0         52    2130          24.6          82
# 395          4         135.0         84    2295          11.6          82
# 396          4         120.0         79    2625          18.6          82
# 397          4         119.0         82    2720          19.4          82
#
#      origin  name
# 0         1    49
# 1         1    36
# 2         1   231
# 3         1    14
# 4         1   161
# ..      ...   ...
# 393       1   153
# 394       2   301
# 395       1   119
# 396       1   159
# 397       1    69
#
# [398 rows x 8 columns]

# %%
y
# Out:
# 0      18.0
# 1      15.0
# 2      18.0
# 3      16.0
# 4      17.0
#        ...
# 393    27.0
# 394    44.0
# 395    32.0
# 396    28.0
# 397    31.0
# Name: mpg, Length: 398, dtype: float64

# %%
sns.distplot(df['acceleration'])

# %%
sns.distplot(df['displacement'])

# %%
df.shape
# Out:
# (398, 9)

# %%
df.head(50)
# Out:
#      mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0   18.0          8         307.0        130    3504          12.0
# 1   15.0          8         350.0        165    3693          11.5
# 2   18.0          8         318.0        150    3436          11.0
# 3   16.0          8         304.0        150    3433          12.0
# 4   17.0          8         302.0        140    3449          10.5
# 5   15.0          8         429.0        198    4341          10.0
# 6   14.0          8         454.0        220    4354           9.0
# 7   14.0          8         440.0        215    4312           8.5
# 8   14.0          8         455.0        225    4425          10.0
# 9   15.0          8         390.0        190    3850           8.5
# 10  15.0          8         383.0        170    3563          10.0
# 11  14.0          8         340.0        160    3609           8.0
# 12  15.0          8         400.0        150    3761           9.5
# 13  14.0          8         455.0        225    3086          10.0
# 14  24.0          4         113.0         95    2372          15.0
# 15  22.0          6         198.0         95    2833          15.5
# 16  18.0          6         199.0         97    2774          15.5
# 17  21.0          6         200.0         85    2587          16.0
# 18  27.0          4          97.0         88    2130          14.5
# 19  26.0          4          97.0         46    1835          20.5
# 20  25.0          4         110.0         87    2672          17.5
# 21  24.0          4         107.0         90    2430          14.5
# 22  25.0          4         104.0         95    2375          17.5
# 23  26.0          4         121.0        113    2234          12.5
# 24  21.0          6         199.0         90    2648          15.0
# 25  10.0          8         360.0        215    4615          14.0
# 26  10.0          8         307.0        200    4376          15.0
# 27  11.0          8         318.0        210    4382          13.5
# 28   9.0          8         304.0        193    4732          18.5
# 29  27.0          4          97.0         88    2130          14.5
# 30  28.0          4         140.0         90    2264          15.5
# 31  25.0          4         113.0         95    2228          14.0
# 32  25.0          4          98.0          ?    2046          19.0
# 33  19.0          6         232.0        100    2634          13.0
# 34  16.0          6         225.0        105    3439          15.5
# 35  17.0          6         250.0        100    3329          15.5
# 36  19.0          6         250.0         88    3302          15.5
# 37  18.0          6         232.0        100    3288          15.5
# 38  14.0          8         350.0        165    4209          12.0
# 39  14.0          8         400.0        175    4464          11.5
# 40  14.0          8         351.0        153    4154          13.5
# 41  14.0          8         318.0        150    4096          13.0
# 42  12.0          8         383.0        180    4955          11.5
# 43  13.0          8         400.0        170    4746          12.0
# 44  13.0          8         400.0        175    5140          12.0
# 45  18.0          6         258.0        110    2962          13.5
# 46  22.0          4         140.0         72    2408          19.0
# 47  19.0          6         250.0        100    3282          15.0
# 48  18.0          6         250.0         88    3139          14.5
# 49  23.0          4         122.0         86    2220          14.0
#
#     model_year  origin  name
# 0           70       1    49
# 1           70       1    36
# 2           70       1   231
# 3           70       1    14
# 4           70       1   161
# 5           70       1   141
# 6           70       1    54
# 7           70       1   223
# 8           70       1   241
# 9           70       1     1
# 10          70       1   101
# 11          70       1   215
# 12          70       1    57
# 13          70       1    30
# 14          70       3   274
# 15          70       1   220
# 16          70       1     8
# 17          70       1   150
# 18          70       3    95
# 19          70       2   282
# 20          70       2   211
# 21          70       2    16
# 22          70       2   258
# 23          70       2    22
# 24          70       1     7
# 25          70       1   133
# 26          70       1    68
# 27          70       1   112
# 28          70       1   163
# 29          71       3    95
# 30          71       1    65
# 31          71       3   271
# 32          71       1   156
# 33          71       1     7
# 34          71       1   232
# 35          71       1    49
# 36          71       1   162
# 37          71       1    10
# 38          71       1    54
# 39          71       1   242
# 40          71       1   141
# 41          71       1   223
# 42          71       1   116
# 43          71       1   129
# 44          71       1   250
# 45          71       1     9
# 46          71       1    64
# 47          71       1   243
# 48          71       1   151
# 49          71       1   187

# %%
df.drop(32,inplace=True)

# %%
df.drop(330,inplace=True)

# %%
df.drop(126,inplace=True)

# %%
df.drop(336,inplace=True)

# %%
df.drop(354,inplace=True)

# %%
df.drop(374,inplace=True)

# %%
df.shape
# Out:
# (392, 9)

# %%
df.dtypes
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower       object
# weight            int64
# acceleration    float64
# model_year        int64
# origin            int64
# name              int32
# dtype: object

# %%
# to change use .astype() 
df['horsepower'] = pd.to_numeric(df['horsepower'], errors='coerce')

# %%
df.dtypes
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower        int64
# weight            int64
# acceleration    float64
# model_year        int64
# origin            int64
# name              int32
# dtype: object

# %%
sns.distplot(df['horsepower'])

# %%
sns.boxplot(x = 'origin', y = 'mpg', data = df)
#1-USA,2-Europe,3-Asia(more mpg)

# %%
sns.boxplot(x = 'cylinders', y = 'mpg', data = df)
#4 cylinder engine consume more fuel,8cylinder consume less

# %%
sns.boxplot(x = 'model_year', y = 'mpg', data = df)
#80 model consumed high,73 model least

# %%
fig = plt.figure(figsize = (12,12))
sns.lineplot(x = 'displacement', y = 'mpg', data = df)

# %%
fig = plt.figure(figsize = (12,12))
sns.lineplot(x = 'acceleration', y = 'mpg', data = df)

# %%
fig = plt.figure(figsize = (12,12))
sns.lineplot(x = 'weight', y = 'mpg', data = df)

# %%
fig = plt.figure(figsize = (12,12))
sns.lineplot(x = 'horsepower', y = 'mpg', data = df)

# %%
#separating the input variable
#regression approach 
import numpy as np
df_x=df.drop(columns=["mpg"])
y=df['mpg']

# %%
#sacaling down using standardscaler
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(df_x)
x=pd.DataFrame(x,columns=df_x.columns)

# %%
x.head()
# Out:
#    cylinders  displacement  horsepower    weight  acceleration  model_year  \
# 0   1.483947      1.077290    0.664133  0.620540     -1.285258   -1.625315
# 1   1.483947      1.488732    1.574594  0.843334     -1.466724   -1.625315
# 2   1.483947      1.182542    1.184397  0.540382     -1.648189   -1.625315
# 3   1.483947      1.048584    1.184397  0.536845     -1.285258   -1.625315
# 4   1.483947      1.029447    0.924265  0.555706     -1.829655   -1.625315
#
#      origin      name
# 0 -0.716641 -1.110620
# 1 -0.716641 -1.255965
# 2 -0.716641  0.924205
# 3 -0.716641 -1.501933
# 4 -0.716641  0.141580

# %%
y.head()
# Out:
# 0    18.0
# 1    15.0
# 2    18.0
# 3    16.0
# 4    17.0
# Name: mpg, dtype: float64

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn import linear_model
max_r_score=-10
for r_state in range(42,101):
    x_train,x_test,y_train,y_test = train_test_split(x,y,random_state=r_state,test_size=0.20)
    regr=linear_model.LinearRegression()
    regr.fit(x_train,y_train)
    y_pred=regr.predict(x_test)
    r2_scr=r2_score(y_test,y_pred)
    print("r2_score corresponding to random state: ",r_state,"is: ",r2_scr)
    if r2_scr>max_r_score:
        max_r_score=r2_scr
        final_r_state=r_state
    print()
    print()
    print("max r2 score corresponding to ", final_r_state,"is",max_r_score)
# Out:
# r2_score corresponding to random state:  42 is:  0.7855211127732882
#
#
# max r2 score corresponding to  42 is 0.7855211127732882
# r2_score corresponding to random state:  43 is:  0.8186954410906715
#
#
# max r2 score corresponding to  43 is 0.8186954410906715
# r2_score corresponding to random state:  44 is:  0.8231788883831871
#
#
# max r2 score corresponding to  44 is 0.8231788883831871
# r2_score corresponding to random state:  45 is:  0.85312637301074
#
#
# max r2 score corresponding to  45 is 0.85312637301074
# r2_score corresponding to random state:  46 is:  0.8442044777459372
#
#
# max r2 score corresponding to  45 is 0.85312637301074
# r2_score corresponding to random state:  47 is:  0.8025333274524913
#
#
# max r2 score corresponding to  45 is 0.85312637301074
# r2_score corresponding to random state:  48 is:  0.7851015242562289
#
#
# max r2 score corresponding to  45 is 0.85312637301074
# r2_score corresponding to random state:  49 is:  0.7691688257001106
#
#
# max r2 score corresponding to  45 is 0.85312637301074
# r2_score corresponding to random state:  50 is:  0.8673802005074108
#
#
# max r2 score corresponding to  50 is 0.8673802005074108
# r2_score corresponding to random state:  51 is:  0.8021458770942766
#
#
# max r2 score corresponding to  50 is 0.8673802005074108
# r2_score corresponding to random state:  52 is:  0.8310540928226808
#
#
# max r2 score corresponding to  50 is 0.8673802005074108
# r2_score corresponding to random state:  53 is:  0.846277111514733
#
#
# max r2 score corresponding to  50 is 0.8673802005074108
# r2_score corresponding to random state:  54 is:  0.8319597391697506
#
#
# max r2 score corresponding to  50 is 0.8673802005074108
# r2_score corresponding to random state:  55 is:  0.8087926274617641
#
#
# max r2 score corresponding to  50 is 0.8673802005074108
# r2_score corresponding to random state:  56 is:  0.8331167496348136
#
#
# max r2 score corresponding to  50 is 0.8673802005074108
# r2_score corresponding to random state:  57 is:  0.7872024989270493
#
#
# max r2 score corresponding to  50 is 0.8673802005074108
# r2_score corresponding to random state:  58 is:  0.8128459359447995
#
#
# max r2 score corresponding to  50 is 0.8673802005074108
# r2_score corresponding to random state:  59 is:  0.8632181401715243
#
#
# max r2 score corresponding to  50 is 0.8673802005074108
# r2_score corresponding to random state:  60 is:  0.8498670978655729
#
#
# max r2 score corresponding to  50 is 0.8673802005074108
# r2_score corresponding to random state:  61 is:  0.8455813569219108
#
#
# max r2 score corresponding to  50 is 0.8673802005074108
# r2_score corresponding to random state:  62 is:  0.7864334439082057
#
#
# max r2 score corresponding to  50 is 0.8673802005074108
# r2_score corresponding to random state:  63 is:  0.8205476214489082
#
#
# max r2 score corresponding to  50 is 0.8673802005074108
# r2_score corresponding to random state:  64 is:  0.8156584007420112
#
#
# max r2 score corresponding to  50 is 0.8673802005074108
# r2_score corresponding to random state:  65 is:  0.8452218994603763
#
#
# max r2 score corresponding to  50 is 0.8673802005074108
# r2_score corresponding to random state:  66 is:  0.8393120431102189
#
#
# max r2 score corresponding to  50 is 0.8673802005074108
# r2_score corresponding to random state:  67 is:  0.7688371402465322
#
#
# max r2 score corresponding to  50 is 0.8673802005074108
# r2_score corresponding to random state:  68 is:  0.813567995003985
#
#
# max r2 score corresponding to  50 is 0.8673802005074108
# r2_score corresponding to random state:  69 is:  0.8355588831243246
#
#
# max r2 score corresponding to  50 is 0.8673802005074108
# r2_score corresponding to random state:  70 is:  0.7680665223468867
#
#
# max r2 score corresponding to  50 is 0.8673802005074108
# r2_score corresponding to random state:  71 is:  0.7686460243446889
#
#
# max r2 score corresponding to  50 is 0.8673802005074108
# r2_score corresponding to random state:  72 is:  0.8242617789807829
#
#
# max r2 score corresponding to  50 is 0.8673802005074108
# r2_score corresponding to random state:  73 is:  0.8354115955030876
#
#
# max r2 score corresponding to  50 is 0.8673802005074108
# r2_score corresponding to random state:  74 is:  0.7647697468548716
#
#
# max r2 score corresponding to  50 is 0.8673802005074108
# r2_score corresponding to random state:  75 is:  0.7818019907830907
#
#
# max r2 score corresponding to  50 is 0.8673802005074108
# r2_score corresponding to random state:  76 is:  0.7826922675667505
#
#
# max r2 score corresponding to  50 is 0.8673802005074108
# r2_score corresponding to random state:  77 is:  0.8078206717228396
#
#
# max r2 score corresponding to  50 is 0.8673802005074108
# r2_score corresponding to random state:  78 is:  0.7762758212736434
#
#
# max r2 score corresponding to  50 is 0.8673802005074108
# r2_score corresponding to random state:  79 is:  0.7502103680982
#
#
# max r2 score corresponding to  50 is 0.8673802005074108
# r2_score corresponding to random state:  80 is:  0.777958185873418
#
#
# max r2 score corresponding to  50 is 0.8673802005074108
# r2_score corresponding to random state:  81 is:  0.7837158713235415
#
#
# max r2 score corresponding to  50 is 0.8673802005074108
# r2_score corresponding to random state:  82 is:  0.8390512560632446
#
#
# max r2 score corresponding to  50 is 0.8673802005074108
# r2_score corresponding to random state:  83 is:  0.804812366713477
#
#
# max r2 score corresponding to  50 is 0.8673802005074108
# r2_score corresponding to random state:  84 is:  0.7811972678415829
#
#
# max r2 score corresponding to  50 is 0.8673802005074108
# r2_score corresponding to random state:  85 is:  0.8106402942067417
#
#
# max r2 score corresponding to  50 is 0.8673802005074108
# r2_score corresponding to random state:  86 is:  0.7987890360158804
#
#
# max r2 score corresponding to  50 is 0.8673802005074108
# r2_score corresponding to random state:  87 is:  0.8353446643388289
#
#
# max r2 score corresponding to  50 is 0.8673802005074108
# r2_score corresponding to random state:  88 is:  0.8383121257120527
#
#
# max r2 score corresponding to  50 is 0.8673802005074108
# r2_score corresponding to random state:  89 is:  0.8071621956465153
#
#
# max r2 score corresponding to  50 is 0.8673802005074108
# r2_score corresponding to random state:  90 is:  0.8104103381582131
#
#
# max r2 score corresponding to  50 is 0.8673802005074108
# r2_score corresponding to random state:  91 is:  0.7836719465514097
#
#
# max r2 score corresponding to  50 is 0.8673802005074108
# r2_score corresponding to random state:  92 is:  0.8500141106894985
#
#
# max r2 score corresponding to  50 is 0.8673802005074108
# r2_score corresponding to random state:  93 is:  0.7953330551404603
#
#
# max r2 score corresponding to  50 is 0.8673802005074108
# r2_score corresponding to random state:  94 is:  0.8207344186997207
#
#
# max r2 score corresponding to  50 is 0.8673802005074108
# r2_score corresponding to random state:  95 is:  0.8308770621063406
#
#
# max r2 score corresponding to  50 is 0.8673802005074108
# r2_score corresponding to random state:  96 is:  0.8234088995501353
#
#
# max r2 score corresponding to  50 is 0.8673802005074108
# r2_score corresponding to random state:  97 is:  0.7871175954220997
#
#
# max r2 score corresponding to  50 is 0.8673802005074108
# r2_score corresponding to random state:  98 is:  0.7896350949626465
#
#
# max r2 score corresponding to  50 is 0.8673802005074108
# r2_score corresponding to random state:  99 is:  0.7961305158544277
#
#
# max r2 score corresponding to  50 is 0.8673802005074108
# r2_score corresponding to random state:  100 is:  0.8076850723673912
#
#
# max r2 score corresponding to  50 is 0.8673802005074108

# %%
#max r2 score corresponding to  50 is 0.86
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=50,test_size=.25)
lr=linear_model.LinearRegression()
lr.fit(x_train,y_train)
y_pred=lr.predict(x_test)

# %%
# Lets evaluate RMSC and r2 score
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
import numpy as np
print("r2 score is : ",r2_score(y_test,y_pred))
print("RMSC is : ",np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# r2 score is :  0.8465925584261919
# RMSC is :  2.570050757597543

# %%
#lets do cross validation
from sklearn.model_selection import cross_val_score
cross_val_score(linear_model.LinearRegression(),x,y,cv=5,scoring="r2")
# Out:
# array([0.56576039, 0.693437  , 0.81240992, 0.68456974, 0.23353813])

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsRegressor
neighbors={"n_neighbors":range(1,30)}
knr=KNeighborsRegressor()
gknr=GridSearchCV(knr,neighbors,cv=10)
gknr.fit(x,y)
# Out:
# C:\Users\Admin\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:814: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# GridSearchCV(cv=10, error_score='raise-deprecating',
#              estimator=KNeighborsRegressor(algorithm='auto', leaf_size=30,
#                                            metric='minkowski',
#                                            metric_params=None, n_jobs=None,
#                                            n_neighbors=5, p=2,
#                                            weights='uniform'),
#              iid='warn', n_jobs=None, param_grid={'n_neighbors': range(1, 30)},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=0)

# %%
gknr.best_params_
# Out:
# {'n_neighbors': 5}

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn import linear_model
def maxr2_score(regr,x,y):
    max_r_score=-10
    for r_state in range(42,101):
        x_train,x_test,y_train,y_test = train_test_split(x,y,random_state=r_state,test_size=0.20)
        regr=linear_model.LinearRegression()
        regr.fit(x_train,y_train)
        y_pred=regr.predict(x_test)
        r2_scr=r2_score(y_test,y_pred)
        print("r2_score corresponding to random state: ",r_state,"is: ",r2_scr)
        if r2_scr>max_r_score:
            max_r_score=r2_scr
            final_r_state=r_state
    print("max r2 score corresponding to ", final_r_state,"is",max_r_score)
    return final_r_state

# %%
from sklearn.linear_model import LinearRegression
lrreg=LinearRegression()
r_state=maxr2_score(lrreg,x,y)
# Out:
# r2_score corresponding to random state:  42 is:  0.7855211127732882
# r2_score corresponding to random state:  43 is:  0.8186954410906715
# r2_score corresponding to random state:  44 is:  0.8231788883831871
# r2_score corresponding to random state:  45 is:  0.85312637301074
# r2_score corresponding to random state:  46 is:  0.8442044777459372
# r2_score corresponding to random state:  47 is:  0.8025333274524913
# r2_score corresponding to random state:  48 is:  0.7851015242562289
# r2_score corresponding to random state:  49 is:  0.7691688257001106
# r2_score corresponding to random state:  50 is:  0.8673802005074108
# r2_score corresponding to random state:  51 is:  0.8021458770942766
# r2_score corresponding to random state:  52 is:  0.8310540928226808
# r2_score corresponding to random state:  53 is:  0.846277111514733
# r2_score corresponding to random state:  54 is:  0.8319597391697506
# r2_score corresponding to random state:  55 is:  0.8087926274617641
# r2_score corresponding to random state:  56 is:  0.8331167496348136
# r2_score corresponding to random state:  57 is:  0.7872024989270493
# r2_score corresponding to random state:  58 is:  0.8128459359447995
# r2_score corresponding to random state:  59 is:  0.8632181401715243
# r2_score corresponding to random state:  60 is:  0.8498670978655729
# r2_score corresponding to random state:  61 is:  0.8455813569219108
# r2_score corresponding to random state:  62 is:  0.7864334439082057
# r2_score corresponding to random state:  63 is:  0.8205476214489082
# r2_score corresponding to random state:  64 is:  0.8156584007420112
# r2_score corresponding to random state:  65 is:  0.8452218994603763
# r2_score corresponding to random state:  66 is:  0.8393120431102189
# r2_score corresponding to random state:  67 is:  0.7688371402465322
# r2_score corresponding to random state:  68 is:  0.813567995003985
# r2_score corresponding to random state:  69 is:  0.8355588831243246
# r2_score corresponding to random state:  70 is:  0.7680665223468867
# r2_score corresponding to random state:  71 is:  0.7686460243446889
# r2_score corresponding to random state:  72 is:  0.8242617789807829
# r2_score corresponding to random state:  73 is:  0.8354115955030876
# r2_score corresponding to random state:  74 is:  0.7647697468548716
# r2_score corresponding to random state:  75 is:  0.7818019907830907
# r2_score corresponding to random state:  76 is:  0.7826922675667505
# r2_score corresponding to random state:  77 is:  0.8078206717228396
# r2_score corresponding to random state:  78 is:  0.7762758212736434
# r2_score corresponding to random state:  79 is:  0.7502103680982
# r2_score corresponding to random state:  80 is:  0.777958185873418
# r2_score corresponding to random state:  81 is:  0.7837158713235415
# r2_score corresponding to random state:  82 is:  0.8390512560632446
# r2_score corresponding to random state:  83 is:  0.804812366713477
# r2_score corresponding to random state:  84 is:  0.7811972678415829
# r2_score corresponding to random state:  85 is:  0.8106402942067417
# r2_score corresponding to random state:  86 is:  0.7987890360158804
# r2_score corresponding to random state:  87 is:  0.8353446643388289
# r2_score corresponding to random state:  88 is:  0.8383121257120527
# r2_score corresponding to random state:  89 is:  0.8071621956465153
# r2_score corresponding to random state:  90 is:  0.8104103381582131
# r2_score corresponding to random state:  91 is:  0.7836719465514097
# r2_score corresponding to random state:  92 is:  0.8500141106894985
# r2_score corresponding to random state:  93 is:  0.7953330551404603
# r2_score corresponding to random state:  94 is:  0.8207344186997207
# r2_score corresponding to random state:  95 is:  0.8308770621063406
# r2_score corresponding to random state:  96 is:  0.8234088995501353
# r2_score corresponding to random state:  97 is:  0.7871175954220997
# r2_score corresponding to random state:  98 is:  0.7896350949626465
# r2_score corresponding to random state:  99 is:  0.7961305158544277
# r2_score corresponding to random state:  100 is:  0.8076850723673912
# max r2 score corresponding to  50 is 0.8673802005074108

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsRegressor
neighbors={"n_neighbors":range(1,30)}
knr=KNeighborsRegressor()
gknr=GridSearchCV(knr,neighbors,cv=10)
gknr.fit(x,y)
# Out:
# C:\Users\Admin\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:814: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# GridSearchCV(cv=10, error_score='raise-deprecating',
#              estimator=KNeighborsRegressor(algorithm='auto', leaf_size=30,
#                                            metric='minkowski',
#                                            metric_params=None, n_jobs=None,
#                                            n_neighbors=5, p=2,
#                                            weights='uniform'),
#              iid='warn', n_jobs=None, param_grid={'n_neighbors': range(1, 30)},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=0)

# %%
gknr.best_params_
# Out:
# {'n_neighbors': 5}

# %%
#knn max r2 score
knr=KNeighborsRegressor(n_neighbors=18)
r_state=maxr2_score(knr,x,y)
# Out:
# r2_score corresponding to random state:  42 is:  0.7855211127732882
# r2_score corresponding to random state:  43 is:  0.8186954410906715
# r2_score corresponding to random state:  44 is:  0.8231788883831871
# r2_score corresponding to random state:  45 is:  0.85312637301074
# r2_score corresponding to random state:  46 is:  0.8442044777459372
# r2_score corresponding to random state:  47 is:  0.8025333274524913
# r2_score corresponding to random state:  48 is:  0.7851015242562289
# r2_score corresponding to random state:  49 is:  0.7691688257001106
# r2_score corresponding to random state:  50 is:  0.8673802005074108
# r2_score corresponding to random state:  51 is:  0.8021458770942766
# r2_score corresponding to random state:  52 is:  0.8310540928226808
# r2_score corresponding to random state:  53 is:  0.846277111514733
# r2_score corresponding to random state:  54 is:  0.8319597391697506
# r2_score corresponding to random state:  55 is:  0.8087926274617641
# r2_score corresponding to random state:  56 is:  0.8331167496348136
# r2_score corresponding to random state:  57 is:  0.7872024989270493
# r2_score corresponding to random state:  58 is:  0.8128459359447995
# r2_score corresponding to random state:  59 is:  0.8632181401715243
# r2_score corresponding to random state:  60 is:  0.8498670978655729
# r2_score corresponding to random state:  61 is:  0.8455813569219108
# r2_score corresponding to random state:  62 is:  0.7864334439082057
# r2_score corresponding to random state:  63 is:  0.8205476214489082
# r2_score corresponding to random state:  64 is:  0.8156584007420112
# r2_score corresponding to random state:  65 is:  0.8452218994603763
# r2_score corresponding to random state:  66 is:  0.8393120431102189
# r2_score corresponding to random state:  67 is:  0.7688371402465322
# r2_score corresponding to random state:  68 is:  0.813567995003985
# r2_score corresponding to random state:  69 is:  0.8355588831243246
# r2_score corresponding to random state:  70 is:  0.7680665223468867
# r2_score corresponding to random state:  71 is:  0.7686460243446889
# r2_score corresponding to random state:  72 is:  0.8242617789807829
# r2_score corresponding to random state:  73 is:  0.8354115955030876
# r2_score corresponding to random state:  74 is:  0.7647697468548716
# r2_score corresponding to random state:  75 is:  0.7818019907830907
# r2_score corresponding to random state:  76 is:  0.7826922675667505
# r2_score corresponding to random state:  77 is:  0.8078206717228396
# r2_score corresponding to random state:  78 is:  0.7762758212736434
# r2_score corresponding to random state:  79 is:  0.7502103680982
# r2_score corresponding to random state:  80 is:  0.777958185873418
# r2_score corresponding to random state:  81 is:  0.7837158713235415
# r2_score corresponding to random state:  82 is:  0.8390512560632446
# r2_score corresponding to random state:  83 is:  0.804812366713477
# r2_score corresponding to random state:  84 is:  0.7811972678415829
# r2_score corresponding to random state:  85 is:  0.8106402942067417
# r2_score corresponding to random state:  86 is:  0.7987890360158804
# r2_score corresponding to random state:  87 is:  0.8353446643388289
# r2_score corresponding to random state:  88 is:  0.8383121257120527
# r2_score corresponding to random state:  89 is:  0.8071621956465153
# r2_score corresponding to random state:  90 is:  0.8104103381582131
# r2_score corresponding to random state:  91 is:  0.7836719465514097
# r2_score corresponding to random state:  92 is:  0.8500141106894985
# r2_score corresponding to random state:  93 is:  0.7953330551404603
# r2_score corresponding to random state:  94 is:  0.8207344186997207
# r2_score corresponding to random state:  95 is:  0.8308770621063406
# r2_score corresponding to random state:  96 is:  0.8234088995501353
# r2_score corresponding to random state:  97 is:  0.7871175954220997
# r2_score corresponding to random state:  98 is:  0.7896350949626465
# r2_score corresponding to random state:  99 is:  0.7961305158544277
# r2_score corresponding to random state:  100 is:  0.8076850723673912
# max r2 score corresponding to  50 is 0.8673802005074108

# %%
from sklearn.model_selection import cross_val_score
print("Mean r2 score for Linear Regression:",cross_val_score(lrreg,x,y,cv=5,scoring="r2").mean())
print("standard deviation in r2 score for Linear Regression:",cross_val_score(lrreg,x,y,cv=5,scoring='r2').std())
print()
print("Mean r2 score for KNN Regression: ",cross_val_score(knr,x,y,cv=5,scoring="r2").mean())
print("standard deviation in r2 score for KNN Regression:",cross_val_score(knr,x,y,cv=5,scoring="r2").std())
# based on output KNN Regression is Performing well
# Out:
# Mean r2 score for Linear Regression: 0.5979430357603732
# standard deviation in r2 score for Linear Regression: 0.19821502830559654
#
# Mean r2 score for KNN Regression:  0.628864892928606
# standard deviation in r2 score for KNN Regression: 0.29688581248216217

# %%
from sklearn.linear_model import Lasso
lsreg=Lasso()
parameters={"alpha":[0.001,0.01,0.1,1]}
clf=GridSearchCV(lsreg,parameters,cv=10)
clf.fit(x,y)
# Out:
# C:\Users\Admin\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:814: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# GridSearchCV(cv=10, error_score='raise-deprecating',
#              estimator=Lasso(alpha=1.0, copy_X=True, fit_intercept=True,
#                              max_iter=1000, normalize=False, positive=False,
#                              precompute=False, random_state=None,
#                              selection='cyclic', tol=0.0001, warm_start=False),
#              iid='warn', n_jobs=None,
#              param_grid={'alpha': [0.001, 0.01, 0.1, 1]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=0)

# %%
clf.best_params_
# Out:
# {'alpha': 0.001}

# %%
lsreg=Lasso(alpha=0.001)
r_state=maxr2_score(lsreg,x,y)
# Out:
# r2_score corresponding to random state:  42 is:  0.7855211127732882
# r2_score corresponding to random state:  43 is:  0.8186954410906715
# r2_score corresponding to random state:  44 is:  0.8231788883831871
# r2_score corresponding to random state:  45 is:  0.85312637301074
# r2_score corresponding to random state:  46 is:  0.8442044777459372
# r2_score corresponding to random state:  47 is:  0.8025333274524913
# r2_score corresponding to random state:  48 is:  0.7851015242562289
# r2_score corresponding to random state:  49 is:  0.7691688257001106
# r2_score corresponding to random state:  50 is:  0.8673802005074108
# r2_score corresponding to random state:  51 is:  0.8021458770942766
# r2_score corresponding to random state:  52 is:  0.8310540928226808
# r2_score corresponding to random state:  53 is:  0.846277111514733
# r2_score corresponding to random state:  54 is:  0.8319597391697506
# r2_score corresponding to random state:  55 is:  0.8087926274617641
# r2_score corresponding to random state:  56 is:  0.8331167496348136
# r2_score corresponding to random state:  57 is:  0.7872024989270493
# r2_score corresponding to random state:  58 is:  0.8128459359447995
# r2_score corresponding to random state:  59 is:  0.8632181401715243
# r2_score corresponding to random state:  60 is:  0.8498670978655729
# r2_score corresponding to random state:  61 is:  0.8455813569219108
# r2_score corresponding to random state:  62 is:  0.7864334439082057
# r2_score corresponding to random state:  63 is:  0.8205476214489082
# r2_score corresponding to random state:  64 is:  0.8156584007420112
# r2_score corresponding to random state:  65 is:  0.8452218994603763
# r2_score corresponding to random state:  66 is:  0.8393120431102189
# r2_score corresponding to random state:  67 is:  0.7688371402465322
# r2_score corresponding to random state:  68 is:  0.813567995003985
# r2_score corresponding to random state:  69 is:  0.8355588831243246
# r2_score corresponding to random state:  70 is:  0.7680665223468867
# r2_score corresponding to random state:  71 is:  0.7686460243446889
# r2_score corresponding to random state:  72 is:  0.8242617789807829
# r2_score corresponding to random state:  73 is:  0.8354115955030876
# r2_score corresponding to random state:  74 is:  0.7647697468548716
# r2_score corresponding to random state:  75 is:  0.7818019907830907
# r2_score corresponding to random state:  76 is:  0.7826922675667505
# r2_score corresponding to random state:  77 is:  0.8078206717228396
# r2_score corresponding to random state:  78 is:  0.7762758212736434
# r2_score corresponding to random state:  79 is:  0.7502103680982
# r2_score corresponding to random state:  80 is:  0.777958185873418
# r2_score corresponding to random state:  81 is:  0.7837158713235415
# r2_score corresponding to random state:  82 is:  0.8390512560632446
# r2_score corresponding to random state:  83 is:  0.804812366713477
# r2_score corresponding to random state:  84 is:  0.7811972678415829
# r2_score corresponding to random state:  85 is:  0.8106402942067417
# r2_score corresponding to random state:  86 is:  0.7987890360158804
# r2_score corresponding to random state:  87 is:  0.8353446643388289
# r2_score corresponding to random state:  88 is:  0.8383121257120527
# r2_score corresponding to random state:  89 is:  0.8071621956465153
# r2_score corresponding to random state:  90 is:  0.8104103381582131
# r2_score corresponding to random state:  91 is:  0.7836719465514097
# r2_score corresponding to random state:  92 is:  0.8500141106894985
# r2_score corresponding to random state:  93 is:  0.7953330551404603
# r2_score corresponding to random state:  94 is:  0.8207344186997207
# r2_score corresponding to random state:  95 is:  0.8308770621063406
# r2_score corresponding to random state:  96 is:  0.8234088995501353
# r2_score corresponding to random state:  97 is:  0.7871175954220997
# r2_score corresponding to random state:  98 is:  0.7896350949626465
# r2_score corresponding to random state:  99 is:  0.7961305158544277
# r2_score corresponding to random state:  100 is:  0.8076850723673912
# max r2 score corresponding to  50 is 0.8673802005074108

# %%
from sklearn.model_selection import cross_val_score
print("Mean r2 score for Lasso Regression:",cross_val_score(lsreg,x,y,cv=5,scoring="r2").mean())
print("standard deviation in r2 score for Lasso Regression:",cross_val_score(lsreg,x,y,cv=5,scoring='r2').std())
# based on output Lasso Regression is Performing as linear Regression
# Out:
# Mean r2 score for Lasso Regression: 0.5976682491799898
# standard deviation in r2 score for Lasso Regression: 0.19872796617155147

# %%
# gradient Boosting
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import GradientBoostingRegressor
import warnings
warnings.filterwarnings("ignore")
gbr=GradientBoostingRegressor()
parameters={"learning_rate":[0.001,0.01,0.1,1],"n_estimators":[10,100,500,1000]}
clf=GridSearchCV(gbr,parameters,cv=5)
clf.fit(x,y)
# Out:
# GridSearchCV(cv=5, error_score='raise-deprecating',
#              estimator=GradientBoostingRegressor(alpha=0.9,
#                                                  criterion='friedman_mse',
#                                                  init=None, learning_rate=0.1,
#                                                  loss='ls', max_depth=3,
#                                                  max_features=None,
#                                                  max_leaf_nodes=None,
#                                                  min_impurity_decrease=0.0,
#                                                  min_impurity_split=None,
#                                                  min_samples_leaf=1,
#                                                  min_samples_split=2,
#                                                  min_weight_fraction_leaf=0.0,
#                                                  n_estimators=100,
#                                                  n_iter_no_change=None,
#                                                  presort='auto',
#                                                  random_state=None,
#                                                  subsample=1.0, tol=0.0001,
#                                                  validation_fraction=0.1,
#                                                  verbose=0, warm_start=False),
#              iid='warn', n_jobs=None,
#              param_grid={'learning_rate': [0.001, 0.01, 0.1, 1],
#                          'n_estimators': [10, 100, 500, 1000]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=0)

# %%
clf.best_params_
# Out:
# {'learning_rate': 0.01, 'n_estimators': 1000}

# %%
# gradient Boosting
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import GradientBoostingRegressor
import warnings
warnings.filterwarnings("ignore")
gbr=GradientBoostingRegressor(learning_rate= 0.01, n_estimators= 1000)
parameters={"learning_rate":[0.001,0.01,0.1,1],"n_estimators":[10,100,500,1000]}
clf=GridSearchCV(gbr,parameters,cv=5)
clf.fit(x,y)
# Out:
# GridSearchCV(cv=5, error_score='raise-deprecating',
#              estimator=GradientBoostingRegressor(alpha=0.9,
#                                                  criterion='friedman_mse',
#                                                  init=None, learning_rate=0.01,
#                                                  loss='ls', max_depth=3,
#                                                  max_features=None,
#                                                  max_leaf_nodes=None,
#                                                  min_impurity_decrease=0.0,
#                                                  min_impurity_split=None,
#                                                  min_samples_leaf=1,
#                                                  min_samples_split=2,
#                                                  min_weight_fraction_leaf=0.0,
#                                                  n_estimators=1000,
#                                                  n_iter_no_change=None,
#                                                  presort='auto',
#                                                  random_state=None,
#                                                  subsample=1.0, tol=0.0001,
#                                                  validation_fraction=0.1,
#                                                  verbose=0, warm_start=False),
#              iid='warn', n_jobs=None,
#              param_grid={'learning_rate': [0.001, 0.01, 0.1, 1],
#                          'n_estimators': [10, 100, 500, 1000]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=0)

# %%
from sklearn.model_selection import cross_val_score
print("Mean r2 score for Gradientboosting Regressor:",cross_val_score(gbr,x,y,cv=5,scoring="r2").mean())
print("standard deviation in r2 score for GradientbootingRegressir:",cross_val_score(gbr,x,y,cv=5,scoring="r2").std())
# Out:
# Mean r2 score for Gradientboosting Regressor: 0.7762271097395119
# standard deviation in r2 score for GradientbootingRegressir: 0.15037792134507585

# %%
from sklearn.ensemble import AdaBoostRegressor
from sklearn.tree import DecisionTreeRegressor
ada_reg=AdaBoostRegressor()
parameters={"learning_rate":[0.001,0.01,0.1,1],"n_estimators":[10,100,500,1000],"base_estimator":[lrreg,lsreg,DecisionTreeRegressor()]}
clf=GridSearchCV(ada_reg,parameters,cv=5)
clf.fit(x,y)
# Out:
# GridSearchCV(cv=5, error_score='raise-deprecating',
#              estimator=AdaBoostRegressor(base_estimator=None, learning_rate=1.0,
#                                          loss='linear', n_estimators=50,
#                                          random_state=None),
#              iid='warn', n_jobs=None,
#              param_grid={'base_estimator': [LinearRegression(copy_X=True,
#                                                              fit_intercept=True,
#                                                              n_jobs=None,
#                                                              normalize=False),
#                                             Lasso(alpha=0.001, copy_X=True,
#                                                   fit_intercept=True,
#                                                   max_it...
#                                                                   max_features=None,
#                                                                   max_leaf_nodes=None,
#                                                                   min_impurity_decrease=0.0,
#                                                                   min_impurity_split=None,
#                                                                   min_samples_leaf=1,
#                                                                   min_samples_split=2,
#                                                                   min_weight_fraction_leaf=0.0,
#                                                                   presort=False,
#                                                                   random_state=None,
#                                                                   splitter='best')],
#                          'learning_rate': [0.001, 0.01, 0.1, 1],
#                          'n_estimators': [10, 100, 500, 1000]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=0)

# %%
clf.best_params_
# Out:
# {'base_estimator': DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#                        max_leaf_nodes=None, min_impurity_decrease=0.0,
#                        min_impurity_split=None, min_samples_leaf=1,
#                        min_samples_split=2, min_weight_fraction_leaf=0.0,
#                        presort=False, random_state=None, splitter='best'),
#  'learning_rate': 1,
#  'n_estimators': 100}

# %%
from sklearn.model_selection import cross_val_score
print("Mean r2 score for adaboosting Regressor:",cross_val_score(ada_reg,x,y,cv=5,scoring="r2").mean())
print("standard deviation in r2 score for adabootingRegressir:",cross_val_score(ada_reg,x,y,cv=5,scoring="r2").std())
# Out:
# Mean r2 score for adaboosting Regressor: 0.7263882131939011
# standard deviation in r2 score for adabootingRegressir: 0.1871991097082799

# %%
from sklearn.ensemble import AdaBoostRegressor
from sklearn.tree import DecisionTreeRegressor
ada_reg=AdaBoostRegressor( learning_rate= 1,n_estimators= 100)
parameters={"learning_rate":[0.001,0.01,0.1,1],"n_estimators":[10,100,500,1000],"base_estimator":[lrreg,lsreg,DecisionTreeRegressor()]}
clf=GridSearchCV(ada_reg,parameters,cv=5)
clf.fit(x,y)
# Out:
# GridSearchCV(cv=5, error_score='raise-deprecating',
#              estimator=AdaBoostRegressor(base_estimator=None, learning_rate=1,
#                                          loss='linear', n_estimators=100,
#                                          random_state=None),
#              iid='warn', n_jobs=None,
#              param_grid={'base_estimator': [LinearRegression(copy_X=True,
#                                                              fit_intercept=True,
#                                                              n_jobs=None,
#                                                              normalize=False),
#                                             Lasso(alpha=0.001, copy_X=True,
#                                                   fit_intercept=True,
#                                                   max_ite...
#                                                                   max_features=None,
#                                                                   max_leaf_nodes=None,
#                                                                   min_impurity_decrease=0.0,
#                                                                   min_impurity_split=None,
#                                                                   min_samples_leaf=1,
#                                                                   min_samples_split=2,
#                                                                   min_weight_fraction_leaf=0.0,
#                                                                   presort=False,
#                                                                   random_state=None,
#                                                                   splitter='best')],
#                          'learning_rate': [0.001, 0.01, 0.1, 1],
#                          'n_estimators': [10, 100, 500, 1000]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=0)

# %%
from sklearn.model_selection import cross_val_score
print("Mean r2 score for adaboosting Regressor:",cross_val_score(ada_reg,x,y,cv=5,scoring="r2").mean())
print("standard deviation in r2 score for adabootingRegressir:",cross_val_score(ada_reg,x,y,cv=5,scoring="r2").std())
# Out:
# Mean r2 score for adaboosting Regressor: 0.6980200625829158
# standard deviation in r2 score for adabootingRegressir: 0.17628982272978141

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
regressor = RandomForestRegressor(n_estimators = 100, random_state = 0)

# %%
regressor.fit(x, y)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#                       max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=100,
#                       n_jobs=None, oob_score=False, random_state=0, verbose=0,
#                       warm_start=False)

# %%
from sklearn.model_selection import cross_val_score
print("Mean r2 score for RandomForest Regressor:",cross_val_score(regressor,x,y,cv=5,scoring="r2").mean())
print("standard deviation in r2 score for RandomForestRegressor:",cross_val_score(regressor,x,y,cv=5,scoring="r2").std())
# Out:
# Mean r2 score for RandomForest Regressor: 0.7445463247461286
# standard deviation in r2 score for RandomForestRegressor: 0.21432727158508066

# %%
#based on the above after boosting Gradiebnt boosting regressor yeilded best result with mean r2 score of 0.77 will choose this

# %%
from sklearn.externals import joblib
joblib.dump(gbr,'gbr.pkl')
# Out:
# ['gbr.pkl']
